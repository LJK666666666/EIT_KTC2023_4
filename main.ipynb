# %%
# !python scripts/visualize_sae_sim_samples.py --weights-dir results --splits train val test --rows 2 --cols 4 --batch-size 16
# Out:
# SAEPipeline loaded: predictor=results\sae_predictor_baseline_1\best.pt, sae=results\sae_baseline_3\best.pt
# Predictor dir: results\sae_predictor_baseline_1
# SAE dir: results\sae_baseline_3
# Output directory: results\sae_predictor_baseline_1\sae_sim_samples_3
# HDF5 path: dataset_sim/level_1/data.h5
# Level: 1
# train: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_3\train_comparison.png
# val: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_3\val_comparison.png
# test: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_3\test_comparison.png
# Summary saved to: results\sae_predictor_baseline_1\sae_sim_samples_3\summary.json
# ...
# Infer: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
#
#
# Infer:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Infer:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# %run scripts/visualize_sae_sim_samples.py --weights-dir results --splits train val test --rows 2 --cols 4 --batch-size 16 --show
# Out:
# SAEPipeline loaded: predictor=results\sae_predictor_baseline_1\best.pt, sae=results\sae_baseline_3\best.pt
# Predictor dir: results\sae_predictor_baseline_1
# SAE dir: results\sae_baseline_3
# Output directory: results\sae_predictor_baseline_1\sae_sim_samples_4
# HDF5 path: dataset_sim/level_1/data.h5
# Level: 1
# train: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_4\train_comparison.png
# val: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_4\val_comparison.png
# test: sampled 8 examples
#   Saved: results\sae_predictor_baseline_1\sae_sim_samples_4\test_comparison.png
# Summary saved to: results\sae_predictor_baseline_1\sae_sim_samples_4\summary.json

# %%
# %run scripts/visualize_sae_sim_samples.py --weights-dir results/sae_predictor_imgloss_2 --splits train val test --rows 2 --cols 4 --batch-size 16 --show
# Out:
# SAEPipeline loaded: predictor=results\sae_predictor_imgloss_2\best.pt, sae=results\sae_baseline_3\best.pt
# Predictor dir: results\sae_predictor_imgloss_2
# SAE dir: results\sae_baseline_3
# Output directory: results\sae_predictor_imgloss_2\sae_sim_samples_2
# HDF5 path: dataset_sim/level_1/data.h5
# Level: 1
# train: sampled 8 examples
#   Saved: results\sae_predictor_imgloss_2\sae_sim_samples_2\train_comparison.png
# val: sampled 8 examples
#   Saved: results\sae_predictor_imgloss_2\sae_sim_samples_2\val_comparison.png
# test: sampled 8 examples
#   Saved: results\sae_predictor_imgloss_2\sae_sim_samples_2\test_comparison.png
# Summary saved to: results\sae_predictor_imgloss_2\sae_sim_samples_2\summary.json

# %%
# %run scripts/visualize_sae_sim_samples.py --weights-dir results/sae_predictor_joint_img_2 --splits train val test --rows 2 --cols 4 --batch-size 16 --show
# Out:
# SAEPipeline: using decoder weights stored in predictor checkpoint
# SAEPipeline loaded: predictor=results\sae_predictor_joint_img_2\best.pt, sae=results\sae_baseline_3\best.pt
# Predictor dir: results\sae_predictor_joint_img_2
# SAE dir: results\sae_baseline_3
# Output directory: results\sae_predictor_joint_img_2\sae_sim_samples_1
# HDF5 path: dataset_sim/level_1/data.h5
# Level: 1
# train: sampled 8 examples
#   Saved: results\sae_predictor_joint_img_2\sae_sim_samples_1\train_comparison.png
# val: sampled 8 examples
#   Saved: results\sae_predictor_joint_img_2\sae_sim_samples_1\val_comparison.png
# test: sampled 8 examples
#   Saved: results\sae_predictor_joint_img_2\sae_sim_samples_1\test_comparison.png
# Summary saved to: results\sae_predictor_joint_img_2\sae_sim_samples_1\summary.json

# %%
# %run scripts/visualize_sae_sim_samples.py --weights-dir results/vq_sae_predictor_baseline_5 --splits train val test --rows 2 --cols 4 --batch-size 16 --show
